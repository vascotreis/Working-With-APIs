# %% [markdown]
# # Use this notbook for your 3 choices of APIs

# %%
import json
import pandas as pd
import requests

response = requests.get('https://api.coinpaprika.com/v1/coins')
#results = response.json()
#results

# %%
data = pd.DataFrame(results)
data.head(10)

# %% [markdown]
# # 2nd API

# %%
resp = requests.get('https://fruityvice.com/api/fruit/all')
resp = resp.json()
#resp

# %%
fruit = pd.DataFrame(resp)
fruit.head(10)
# Out:
#           genus         name  id     family           order  \
# 0         Malus        Apple   6   Rosaceae         Rosales
# 1        Prunus      Apricot  35   Rosaceae         Rosales
# 2        Persea      Avocado  84  Lauraceae        Laurales
# 3          Musa       Banana   1   Musaceae    Zingiberales
# 4         Rubus   Blackberry  64   Rosaceae         Rosales
# 5      Fragaria    Blueberry  33   Rosaceae         Rosales
# 6        Prunus       Cherry   9   Rosaceae         Rosales
# 7     Vaccinium    Cranberry  87  Ericaceae        Ericales
# 8  Selenicereus  Dragonfruit  80  Cactaceae  Caryophyllales
# 9         Durio       Durian  60  Malvaceae        Malvales
#
#                                           nutritions
# 0  {'carbohydrates': 11.4, 'protein': 0.3, 'fat':...
# 1  {'carbohydrates': 3.9, 'protein': 0.5, 'fat': ...
# 2  {'carbohydrates': 8.53, 'protein': 2, 'fat': 1...
# 3  {'carbohydrates': 22, 'protein': 1, 'fat': 0.2...
# 4  {'carbohydrates': 9, 'protein': 1.3, 'fat': 0....
# 5  {'carbohydrates': 5.5, 'protein': 0, 'fat': 0....
# 6  {'carbohydrates': 12, 'protein': 1, 'fat': 0.3...
# 7  {'carbohydrates': 12.2, 'protein': 0.4, 'fat':...
# 8  {'carbohydrates': 9, 'protein': 9, 'fat': 1.5,...
# 9  {'carbohydrates': 27.1, 'protein': 1.5, 'fat':...

# %%
def flatten(fruit, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(fruit[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        fruit = pd.concat([fruit, flattened], axis=1)
        fruit = fruit.drop(column, axis=1)
    return fruit

# %%
dict(fruit['nutritions'])
pd.DataFrame(dict(fruit['nutritions']))
pd.DataFrame(dict(fruit['nutritions'])).transpose()
# Out:
#     carbohydrates  protein    fat  calories  sugar
# 0           11.40     0.30   0.40      52.0  10.30
# 1            3.90     0.50   0.10      15.0   3.20
# 2            8.53     2.00  14.66     160.0   0.66
# 3           22.00     1.00   0.20      96.0  17.20
# 4            9.00     1.30   0.40      40.0   4.50
# 5            5.50     0.00   0.40      29.0   5.40
# 6           12.00     1.00   0.30      50.0   8.00
# 7           12.20     0.40   0.10      46.0   4.00
# 8            9.00     9.00   1.50      60.0   8.00
# 9           27.10     1.50   5.30     147.0   6.75
# 10           8.00     0.60   0.40      44.0   3.00
# 11          19.00     0.80   0.30      74.0  16.00
# 12          10.00     0.90   0.60      44.0   0.00
# 13          18.10     0.72   0.16      69.0  16.00
# 14           3.10     0.40   0.10      21.0   6.40
# 15          14.00     2.60   1.00      68.0   9.00
# 16          15.00     1.10   0.50      61.0   9.00
# 17          14.60     1.14   0.50      61.0   8.90
# 18           9.00     1.10   0.30      29.0   2.50
# 19           8.40     0.30   0.10      25.0   1.70
# 20          11.30     0.75   0.34      50.0   5.74
# 21          17.00     0.80   0.44      66.0  15.00
# 22          15.00     0.82   0.38      60.0  13.70
# 23           8.00     0.00   0.00      34.0   8.00
# 24           9.80     1.44   0.39      43.0   8.10
# 25           8.30     1.00   0.20      43.0   8.20
# 26          11.00     0.00   0.40      43.0   1.00
# 27          22.40     2.20   0.70      97.0  11.20
# 28           9.50     0.90   0.25      39.0   8.40
# 29          15.00     0.40   0.10      57.0  10.00
# 30          18.00     0.00   0.00      81.0  18.00
# 31          13.12     0.54   0.12      50.0   9.85
# 32           7.00     1.00   0.40      36.0   3.00
# 33          11.40     0.70   0.28      46.0   9.92
# 34          18.70     1.70   1.20      83.0  13.70
# 35          12.00     1.20   0.70      53.0   4.40
# 36           5.50     0.80   0.40      29.0   5.40
# 37           8.30     0.00   0.40      45.0   9.10
# 38           3.90     0.90   0.20      74.0   2.60
# 39           8.00     0.60   0.20      30.0   6.00

# %%
nested_columns = ['nutritions']

flat = flatten(fruit, nested_columns)
flat
# Out:
#            genus          name  id           family             order  \
# 0          Malus         Apple   6         Rosaceae           Rosales
# 1         Prunus       Apricot  35         Rosaceae           Rosales
# 2         Persea       Avocado  84        Lauraceae          Laurales
# 3           Musa        Banana   1         Musaceae      Zingiberales
# 4          Rubus    Blackberry  64         Rosaceae           Rosales
# 5       Fragaria     Blueberry  33         Rosaceae           Rosales
# 6         Prunus        Cherry   9         Rosaceae           Rosales
# 7      Vaccinium     Cranberry  87        Ericaceae          Ericales
# 8   Selenicereus   Dragonfruit  80        Cactaceae    Caryophyllales
# 9          Durio        Durian  60        Malvaceae          Malvales
# 10    Sellowiana        Feijoa  76        Myrtaceae        Myrtoideae
# 11         Ficus           Fig  68         Moraceae           Rosales
# 12         Ribes    Gooseberry  69  Grossulariaceae      Saxifragales
# 13         Vitis         Grape  81         Vitaceae           Vitales
# 14         Malus    GreenApple  72         Rosaceae           Rosales
# 15       Psidium         Guava  37        Myrtaceae          Myrtales
# 16       Apteryx          Kiwi  66    Actinidiaceae  Struthioniformes
# 17     Actinidia     Kiwifruit  85    Actinidiaceae          Ericales
# 18        Citrus         Lemon  26         Rutaceae        Sapindales
# 19        Citrus          Lime  44         Rutaceae        Sapindales
# 20     Vaccinium   Lingonberry  65        Ericaceae          Ericales
# 21        Litchi        Lychee  67      Sapindaceae        Sapindales
# 22     Mangifera         Mango  27    Anacardiaceae        Sapindales
# 23       Cucumis         Melon  41    Cucurbitaceae     Cucurbitaceae
# 24         Morus         Morus  82         Moraceae           Rosales
# 25        Citrus        Orange   2         Rutaceae        Sapindales
# 26        Carica        Papaya  42       Caricaceae         Caricacea
# 27    Passiflora  Passionfruit  70   Passifloraceae      Malpighiales
# 28        Prunus         Peach  86         Rosaceae           Rosales
# 29         Pyrus          Pear   4         Rosaceae           Rosales
# 30     Diospyros     Persimmon  52        Ebenaceae           Rosales
# 31        Ananas     Pineapple  10     Bromeliaceae            Poales
# 32     Cactaceae      Pitahaya  78        Cactaceae    Caryophyllales
# 33        Prunus          Plum  71         Rosaceae           Rosales
# 34        Punica   Pomegranate  79       Lythraceae          Myrtales
# 35         Rubus     Raspberry  23         Rosaceae           Rosales
# 36      Fragaria    Strawberry   3         Rosaceae           Rosales
# 37        Citrus     Tangerine  77         Rutaceae        Sapindales
# 38       Solanum        Tomato   5       Solanaceae         Solanales
# 39     Citrullus    Watermelon  25    Cucurbitaceae      Cucurbitales
#
#     nutritions_carbohydrates  nutritions_protein  nutritions_fat  \
# 0                      11.40                0.30            0.40
# 1                       3.90                0.50            0.10
# 2                       8.53                2.00           14.66
# 3                      22.00                1.00            0.20
# 4                       9.00                1.30            0.40
# 5                       5.50                0.00            0.40
# 6                      12.00                1.00            0.30
# 7                      12.20                0.40            0.10
# 8                       9.00                9.00            1.50
# 9                      27.10                1.50            5.30
# 10                      8.00                0.60            0.40
# 11                     19.00                0.80            0.30
# 12                     10.00                0.90            0.60
# 13                     18.10                0.72            0.16
# 14                      3.10                0.40            0.10
# 15                     14.00                2.60            1.00
# 16                     15.00                1.10            0.50
# 17                     14.60                1.14            0.50
# 18                      9.00                1.10            0.30
# 19                      8.40                0.30            0.10
# 20                     11.30                0.75            0.34
# 21                     17.00                0.80            0.44
# 22                     15.00                0.82            0.38
# 23                      8.00                0.00            0.00
# 24                      9.80                1.44            0.39
# 25                      8.30                1.00            0.20
# 26                     11.00                0.00            0.40
# 27                     22.40                2.20            0.70
# 28                      9.50                0.90            0.25
# 29                     15.00                0.40            0.10
# 30                     18.00                0.00            0.00
# 31                     13.12                0.54            0.12
# 32                      7.00                1.00            0.40
# 33                     11.40                0.70            0.28
# 34                     18.70                1.70            1.20
# 35                     12.00                1.20            0.70
# 36                      5.50                0.80            0.40
# 37                      8.30                0.00            0.40
# 38                      3.90                0.90            0.20
# 39                      8.00                0.60            0.20
#
#     nutritions_calories  nutritions_sugar
# 0                  52.0             10.30
# 1                  15.0              3.20
# 2                 160.0              0.66
# 3                  96.0             17.20
# 4                  40.0              4.50
# 5                  29.0              5.40
# 6                  50.0              8.00
# 7                  46.0              4.00
# 8                  60.0              8.00
# 9                 147.0              6.75
# 10                 44.0              3.00
# 11                 74.0             16.00
# 12                 44.0              0.00
# 13                 69.0             16.00
# 14                 21.0              6.40
# 15                 68.0              9.00
# 16                 61.0              9.00
# 17                 61.0              8.90
# 18                 29.0              2.50
# 19                 25.0              1.70
# 20                 50.0              5.74
# 21                 66.0             15.00
# 22                 60.0             13.70
# 23                 34.0              8.00
# 24                 43.0              8.10
# 25                 43.0              8.20
# 26                 43.0              1.00
# 27                 97.0             11.20
# 28                 39.0              8.40
# 29                 57.0             10.00
# 30                 81.0             18.00
# 31                 50.0              9.85
# 32                 36.0              3.00
# 33                 46.0              9.92
# 34                 83.0             13.70
# 35                 53.0              4.40
# 36                 29.0              5.40
# 37                 45.0              9.10
# 38                 74.0              2.60
# 39                 30.0              6.00

# %% [markdown]
# # 3rd API

# %%
# https://whiskyhunter.net/api/auction_data/catawiki/

# %%
whisky = requests.get('https://whiskyhunter.net/api/auction_data/catawiki/')
whisky = whisky.json()
#whisky

# %%
whisky = pd.DataFrame(whisky)
whisky.head(10)
# Out:
#            dt  winning_bid_max  winning_bid_min  winning_bid_mean  \
# 0  2022-12-01          14234.4              2.6            184.13
# 1  2022-11-01           5591.3              4.4            185.15
# 2  2022-10-01           7978.3              2.6            186.43
# 3  2022-09-01           4774.0              6.9            197.89
# 4  2022-08-01           4468.7              7.6            195.02
# 5  2022-07-01          10769.4              2.5            190.26
# 6  2022-06-01           6080.4              2.6            187.23
# 7  2022-05-01          19308.0              1.0            195.52
# 8  2022-04-01          25699.0              1.0            197.58
# 9  2022-03-01           8308.0              1.0            182.61
#
#    auction_trading_volume  auction_lots_count  all_auctions_lots_count  \
# 0               1087289.9                5905                    52852
# 1               1115317.1                6024                    54675
# 2               1092109.0                5858                    49185
# 3                828783.0                4188                    54749
# 4                712988.6                3656                    40669
# 5                797960.0                4194                    47053
# 6                802829.7                4288                    43568
# 7               1003218.2                5131                    45024
# 8                941881.0                4767                    50964
# 9                959411.0                5254                    46175
#
#               auction_name auction_slug
# 0  Catawiki Whisky Auction     catawiki
# 1  Catawiki Whisky Auction     catawiki
# 2  Catawiki Whisky Auction     catawiki
# 3  Catawiki Whisky Auction     catawiki
# 4  Catawiki Whisky Auction     catawiki
# 5  Catawiki Whisky Auction     catawiki
# 6  Catawiki Whisky Auction     catawiki
# 7  Catawiki Whisky Auction     catawiki
# 8  Catawiki Whisky Auction     catawiki
# 9  Catawiki Whisky Auction     catawiki
